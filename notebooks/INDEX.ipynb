# %% [markdown]
# # Notebook index
#
# This small index lists the notebooks in this project and their purpose.

# %%
import pathlib
p = pathlib.Path('.')
for f in sorted(p.glob('*.ipynb')):
    print(f.name)
